# %%
import pandas as pd

file_path = '../raw_data/paris_weather.csv'

df = pd.read_csv(file_path)

print(df)
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    01/01/2021                  3                  2                  7
# 1    02/01/2021                  5                 -1                  7
# 2    03/01/2021                  4                  2                 10
# 3    04/01/2021                  3                  2                 13
# 4    05/01/2021                  3                  2                 14
# ..          ...                ...                ...                ...
# 633  26/09/2022                 17                 12                 26
# 634  27/09/2022                 14                  9                 20
# 635  28/09/2022                 16                 12                 16
# 636  29/09/2022                 15                 10                 12
# 637  30/09/2022                 21                  9                  7
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        2                   3                      3
# 1                        2                   4                      4
# 2                        3                   3                      3
# 3                        2                   2                      3
# 4                        2                   2                      3
# ..                     ...                 ...                    ...
# 633                     13                  17                     13
# 634                      9                  13                     14
# 635                     12                  15                     15
# 636                     11                  12                     14
# 637                      9                  19                     18
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.5                    86              7.750  ...
# 1                    0.1                    76             10.000  ...
# 2                    0.3                    92             10.000  ...
# 3                    1.0                    95              6.875  ...
# 4                    0.4                    94              7.750  ...
# ..                   ...                   ...                ...  ...
# 633                  1.7                    77              8.875  ...
# 634                  0.4                    76              9.875  ...
# 635                  0.4                    67             10.000  ...
# 636                  0.5                    75             10.000  ...
# 637                  0.0                    63             10.000  ...
#
#      WEATHER_CODE_MORNING  WEATHER_CODE_NOON  WEATHER_CODE_EVENING  \
# 0                     116                332                   122
# 1                     122                116                   116
# 2                     122                116                   119
# 3                     332                326                   332
# 4                     326                332                   371
# ..                    ...                ...                   ...
# 633                   119                119                   296
# 634                   119                116                   176
# 635                   116                119                   176
# 636                   116                176                   353
# 637                   113                113                   113
#
#      TOTAL_SNOW_MM  UV_INDEX  SUNHOUR                 OPINION    SUNSET  \
# 0              0.3         1      3.2  météo très défavorable  17:05:00
# 1              0.0         1      8.6  météo très défavorable  17:06:00
# 2              0.0         1      8.6  météo très défavorable  17:07:00
# 3              0.7         1      3.2  météo très défavorable  17:08:00
# 4              0.1         1      3.2  météo très défavorable  17:09:00
# ..             ...       ...      ...                     ...       ...
# 633            0.0         4      6.0       météo défavorable  19:41:00
# 634            0.0         3      6.0          météo correcte  19:38:00
# 635            0.0         3      7.4          météo correcte  19:36:00
# 636            0.0         4      7.4          météo correcte  19:34:00
# 637            0.0         5     11.6         météo favorable  19:32:00
#
#       SUNRISE  TEMPERATURE_NIGHT_C
# 0    08:44:00                    2
# 1    08:44:00                    3
# 2    08:44:00                    3
# 3    08:44:00                    2
# 4    08:43:00                    2
# ..        ...                  ...
# 633  07:43:00                   12
# 634  07:44:00                   10
# 635  07:46:00                   13
# 636  07:47:00                   10
# 637  07:49:00                   10
#
# [638 rows x 25 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

scaler = MinMaxScaler()

df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

print(df)
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    01/01/2021           0.090909           0.290323           0.105263
# 1    02/01/2021           0.136364           0.193548           0.105263
# 2    03/01/2021           0.113636           0.290323           0.184211
# 3    04/01/2021           0.090909           0.290323           0.263158
# 4    05/01/2021           0.090909           0.290323           0.289474
# ..          ...                ...                ...                ...
# 633  26/09/2022           0.409091           0.612903           0.605263
# 634  27/09/2022           0.340909           0.516129           0.447368
# 635  28/09/2022           0.386364           0.612903           0.342105
# 636  29/09/2022           0.363636           0.548387           0.236842
# 637  30/09/2022           0.500000           0.516129           0.105263
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                 0.214286            0.116279               0.136364
# 1                 0.214286            0.139535               0.159091
# 2                 0.250000            0.116279               0.136364
# 3                 0.214286            0.093023               0.136364
# 4                 0.214286            0.093023               0.136364
# ..                     ...                 ...                    ...
# 633               0.607143            0.441860               0.363636
# 634               0.464286            0.348837               0.386364
# 635               0.571429            0.395349               0.409091
# 636               0.535714            0.325581               0.386364
# 637               0.464286            0.488372               0.477273
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0               0.008787              0.823529           0.632653  ...
# 1               0.001757              0.676471           1.000000  ...
# 2               0.005272              0.911765           1.000000  ...
# 3               0.017575              0.955882           0.489796  ...
# 4               0.007030              0.941176           0.632653  ...
# ..                   ...                   ...                ...  ...
# 633             0.029877              0.691176           0.816327  ...
# 634             0.007030              0.676471           0.979592  ...
# 635             0.007030              0.544118           1.000000  ...
# 636             0.008787              0.661765           1.000000  ...
# 637             0.000000              0.485294           1.000000  ...
#
#      WEATHER_CODE_MORNING  WEATHER_CODE_NOON  WEATHER_CODE_EVENING  \
# 0                0.010989           0.848837              0.032967
# 1                0.032967           0.011628              0.010989
# 2                0.032967           0.011628              0.021978
# 3                0.802198           0.825581              0.802198
# 4                0.780220           0.848837              0.945055
# ..                    ...                ...                   ...
# 633              0.021978           0.023256              0.670330
# 634              0.021978           0.011628              0.230769
# 635              0.010989           0.023256              0.230769
# 636              0.010989           0.244186              0.879121
# 637              0.000000           0.000000              0.000000
#
#      TOTAL_SNOW_MM  UV_INDEX   SUNHOUR                 OPINION    SUNSET  \
# 0         0.115385     0.000  0.007692  météo très défavorable  17:05:00
# 1         0.000000     0.000  0.423077  météo très défavorable  17:06:00
# 2         0.000000     0.000  0.423077  météo très défavorable  17:07:00
# 3         0.269231     0.000  0.007692  météo très défavorable  17:08:00
# 4         0.038462     0.000  0.007692  météo très défavorable  17:09:00
# ..             ...       ...       ...                     ...       ...
# 633       0.000000     0.375  0.223077       météo défavorable  19:41:00
# 634       0.000000     0.250  0.223077          météo correcte  19:38:00
# 635       0.000000     0.250  0.330769          météo correcte  19:36:00
# 636       0.000000     0.375  0.330769          météo correcte  19:34:00
# 637       0.000000     0.500  0.653846         météo favorable  19:32:00
#
#       SUNRISE  TEMPERATURE_NIGHT_C
# 0    08:44:00             0.172414
# 1    08:44:00             0.206897
# 2    08:44:00             0.206897
# 3    08:44:00             0.172414
# 4    08:43:00             0.172414
# ..        ...                  ...
# 633  07:43:00             0.517241
# 634  07:44:00             0.448276
# 635  07:46:00             0.551724
# 636  07:47:00             0.448276
# 637  07:49:00             0.448276
#
# [638 rows x 25 columns]
