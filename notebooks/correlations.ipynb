# %%
import pandas as pd
import seaborn as sns
import numpy as np
from datetime import datetime

# %%
# Importing the dataset
df = pd.DataFrame(pd.read_csv('../raw_data/bakerysales.csv'))
df['date'] = pd.to_datetime(df['date'])

# Extract the articles and the quantities in order to transform them into column s through a pivot method.
# We'll now have 149 column, one per product with the corresponding qty
pivot = df[['article', 'Quantity']]
products = pivot.pivot(columns = 'article', values = 'Quantity')

# Merge the pivot table with the original dataset and fill the Nan with zeros
# Now for each date point we have the quantity of the article sold
data = df.merge(products, left_index = True, right_index = True)
data = data.fillna(value = 0)

# Keep only the top 7 products (representing 68% of the volume sold)
# Set date as index
data_target = data[['date', 'TRADITIONAL BAGUETTE', 'CROISSANT', 'COUPE', 'PAIN AU CHOCOLAT', 'BAGUETTE', 'BANETTE', 'CEREAL BAGUETTE']]
data_target = data_target.set_index('date')
data_target = data_target.rename(columns = {'TRADITIONAL BAGUETTE' : 'traditional_baguette',
                                             'CROISSANT' : 'croissant',
                                            'COUPE' : 'coupe',
                                            'PAIN AU CHOCOLAT' : 'pain_au_chocolat',
                                            'BAGUETTE' : 'baguette',
                                            'BANETTE' : 'banette',
                                            'CEREAL BAGUETTE' : 'cereal_baguette'})

data_target = data_target[data_target != 0]
data_target.dropna(axis = 0, how = 'all', inplace = True)
data_target = data_target.fillna(value = 0)

# %%
# Function for converting date in format dd/mm/yyy to yyyy-mm-dd datetime type
def convert_to_date(date_string):
    date_list = date_string.split("/")
    _day, _month, _year = date_list[0], date_list[1], date_list[2]
    date_str = _year+"-"+_month+"-"+_day
    return datetime.strptime(date_str, '%Y-%m-%d').date()

# Load weather data
data_weather = pd.read_csv('../raw_data/paris_weather.csv')
df_weather = data_weather

# Converting date in format dd/mm/yyy to yyyy-mm-dd datetime type
df_weather['date'] = df_weather['DATE'].apply(convert_to_date)
df_weather['date'] = pd.to_datetime(df_weather['date'])


# Creating day of week as a cyclical feature
# First, create the day of the week as a numerical feature
df_weather['day_of_week'] = pd.to_datetime(df_weather['date']).dt.weekday
# Since we have a 7 days week period (e.g., days in a week)
period = 7
# Convert 'day_of_week' to radians
df_weather['day_of_week_radians'] = 2 * np.pi * df_weather['day_of_week'] / period
# Create new features using sine and cosine
df_weather['day_of_week_sin'] = np.sin(df_weather['day_of_week_radians'])
df_weather['day_of_week_cos'] = np.cos(df_weather['day_of_week_radians'])
# Dropping ['month_radians']
df_weather.drop(columns=['day_of_week_radians', 'day_of_week', 'DATE'], inplace=True)


# Creates cyclical month feature according to the date
df_weather['month'] = df_weather.date.dt.month
# Assuming we have a 12 month period (e.g., month in a year)
period = 12
# Convert 'month' to radians
df_weather['month_radians'] = 2 * np.pi * df_weather['month'] / period
# Create new features using sine and cosine
df_weather['month_sin'] = np.sin(df_weather['month_radians'])
df_weather['month_cos'] = np.cos(df_weather['month_radians'])
# Dropping ['month_radians']
df_weather.drop(columns=['month_radians', 'month'], inplace=True)


# Generates periodical features for SUNRISE and SUNSET
# Creates cyclical time feature according to the SUNRISE time
df_weather['sunrise_time'] = pd.to_datetime(df_weather['SUNRISE']).dt.hour*60+pd.to_datetime(df_weather['SUNRISE']).dt.minute
# Assuming we have a 1440 minutes in period (e.g., minutes  in a day)
period = 1440
# Convert 'month' to radians
df_weather['sunrise_time_radians'] = 2 * np.pi * df_weather['sunrise_time'] / period
# Create new features using sine and cosine
df_weather['sunrise_time_sin'] = np.sin(df_weather['sunrise_time_radians'])
df_weather['sunrise_time_cos'] = np.cos(df_weather['sunrise_time_radians'])
# Dropping ['sunrise_time_radians']
df_weather.drop(columns=['sunrise_time_radians', 'sunrise_time', 'SUNRISE'], inplace=True)


# Creates cyclical time feature according to the SUNSET time
df_weather['sunset_time'] = pd.to_datetime(df_weather['SUNSET']).dt.hour*60+pd.to_datetime(df_weather['SUNSET']).dt.minute
# Assuming we have a 1440 minutes in period (e.g., minutes  in a day)
period = 1440
# Convert 'month' to radians
df_weather['sunset_time_radians'] = 2 * np.pi * df_weather['sunset_time'] / period
# Create new features using sine and cosine
df_weather['sunset_time_sin'] = np.sin(df_weather['sunset_time_radians'])
df_weather['sunset_time_cos'] = np.cos(df_weather['sunset_time_radians'])
# Dropping ['sunset_time_radians']
df_weather.drop(columns=['sunset_time_radians', 'sunset_time', 'SUNSET'], inplace=True)


# Setting new date column as index
df_weather.set_index(['date'], inplace=True)
df_weather.head()


# Creating the dictionary for the weather comments and converting OPINION to numbers
dict_meteo = {
'météo idéale': 4,
'météo favorable': 3,
'météo correcte': 2,
'météo défavorable': 1,
'météo très défavorable': 0
}
df_weather['opinion'] = df_weather['OPINION'].map(dict_meteo)
df_weather.drop(columns= ['OPINION'], inplace=True)
df_weather.head()


# Creates dictionary with Holidays
holidays = [
    '2021-1-1',
    '2021-4-5',
    '2021-5-1',
    '2021-5-8',
    '2021-5-13',
    '2021-5-24',
    '2021-7-14',
    '2021-8-15',
    '2021-11-1',
    '2021-11-11',
    '2021-12-25',
    '2022-1-1',
    '2022-4-18',
    '2022-5-1',
    '2022-5-8',
    '2022-5-26',
    '2022-6-6',
    '2022-7-14',
    '2022-8-15',
]
holidays = [pd.to_datetime(holiday)for holiday in holidays ]
# Add isHoliday column to the df_weather
df_weather['isHoliday'] = df_weather.index.map(lambda x: 1 if x in holidays else 0)
# Out:
# /tmp/ipykernel_15907/2798625152.py:46: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_weather['sunrise_time'] = pd.to_datetime(df_weather['SUNRISE']).dt.hour*60+pd.to_datetime(df_weather['SUNRISE']).dt.minute
# /tmp/ipykernel_15907/2798625152.py:46: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_weather['sunrise_time'] = pd.to_datetime(df_weather['SUNRISE']).dt.hour*60+pd.to_datetime(df_weather['SUNRISE']).dt.minute
# /tmp/ipykernel_15907/2798625152.py:59: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_weather['sunset_time'] = pd.to_datetime(df_weather['SUNSET']).dt.hour*60+pd.to_datetime(df_weather['SUNSET']).dt.minute
# /tmp/ipykernel_15907/2798625152.py:59: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_weather['sunset_time'] = pd.to_datetime(df_weather['SUNSET']).dt.hour*60+pd.to_datetime(df_weather['SUNSET']).dt.minute

# %%
merged_data = data_target.merge(df_weather, left_index = True, right_index = True)

# %%
traditional_baguette = merged_data.drop(['croissant', 'coupe', 'pain_au_chocolat', 'baguette', 'banette', 'cereal_baguette'], axis = 1)
croissant = merged_data.drop(['traditional_baguette', 'coupe', 'pain_au_chocolat', 'baguette', 'banette', 'cereal_baguette'], axis = 1)
coupe = merged_data.drop(['traditional_baguette', 'croissant', 'pain_au_chocolat', 'baguette', 'banette', 'cereal_baguette'], axis = 1)
pain_au_chocolat = merged_data.drop(['traditional_baguette', 'coupe', 'croissant', 'baguette', 'banette', 'cereal_baguette'], axis = 1)
baguette = merged_data.drop(['traditional_baguette', 'coupe', 'pain_au_chocolat', 'croissant', 'banette', 'cereal_baguette'], axis = 1)
banette = merged_data.drop(['traditional_baguette', 'coupe', 'pain_au_chocolat', 'baguette', 'croissant', 'cereal_baguette'], axis = 1)
cereal_baguette = merged_data.drop(['traditional_baguette', 'coupe', 'pain_au_chocolat', 'baguette', 'banette', 'croissant'], axis = 1)

# %%
tradi_corr = traditional_baguette.corr()
tradi_corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_9f437_row0_col0, #T_9f437_row1_col1, #T_9f437_row2_col2, #T_9f437_row3_col3, #T_9f437_row4_col4, #T_9f437_row5_col5, #T_9f437_row6_col6, #T_9f437_row7_col7, #T_9f437_row8_col8, #T_9f437_row9_col9, #T_9f437_row10_col10, #T_9f437_row11_col11, #T_9f437_row12_col12, #T_9f437_row13_col13, #T_9f437_row14_col14, #T_9f437_row15_col15, #T_9f437_row16_col16, #T_9f437_row17_col17, #T_9f437_row18_col18, #T_9f437_row19_col19, #T_9f437_row20_col20, #T_9f437_row21_col21, #T_9f437_row22_col22, #T_9f437_row23_col23, #T_9f437_row24_col24, #T_9f437_row25_col25, #T_9f437_row26_col26, #T_9f437_row27_col27, #T_9f437_row28_col28, #T_9f437_row29_col29, #T_9f437_row30_col30, #T_9f437_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9f437_row0_col1, #T_9f437_row0_col5, #T_9f437_row0_col6, #T_9f437_row3_col26, #T_9f437_row15_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_9f437_row0_col2, #T_9f437_row0_col4, #T_9f437_row0_col21, #T_9f437_row18_col29, #T_9f437_row22_col19, #T_9f437_row31_col24 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_9f437_row0_col3, #T_9f437_row8_col20 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_9f437_row0_col7, #T_9f437_row0_col10, #T_9f437_row7_col6, #T_9f437_row15_col20, #T_9f437_row29_col7, #T_9f437_row31_col9 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_9f437_row0_col8, #T_9f437_row4_col11, #T_9f437_row11_col26, #T_9f437_row11_col28, #T_9f437_row21_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_9f437_row0_col9, #T_9f437_row13_col17, #T_9f437_row15_col3, #T_9f437_row18_col20, #T_9f437_row23_col8, #T_9f437_row23_col13, #T_9f437_row23_col16 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_9f437_row0_col11, #T_9f437_row3_col8, #T_9f437_row7_col2, #T_9f437_row13_col7, #T_9f437_row17_col4, #T_9f437_row23_col2, #T_9f437_row24_col16, #T_9f437_row27_col7, #T_9f437_row31_col30 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_9f437_row0_col12, #T_9f437_row7_col14, #T_9f437_row10_col29, #T_9f437_row16_col28, #T_9f437_row17_col3, #T_9f437_row22_col13, #T_9f437_row25_col10 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T
{
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d8833_row0_col23, #T_d8833_row2_col3, #T_d8833_row8_col22, #T_d8833_row23_col0, #T_d8833_row24_col23, #T_d8833_row25_col4, #T_d8833_row25_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d8833_row0_col24, #T_d8833_row11_col13, #T_d8833_row15_col26, #T_d8833_row18_col28 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_d8833_row0_col25, #T_d8833_row7_col29, #T_d8833_row16_col25, #T_d8833_row22_col14, #T_d8833_row23_col29 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_d8833_row0_col26, #T_d8833_row3_col17, #T_d8833_row22_col12 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_d8833_row0_col27, #T_d8833_row3_col16, #T_d8833_row15_col25, #T_d8833_row16_col24, #T_d8833_row22_col2, #T_d8833_row22_col4, #T_d8833_row22_col26 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_d8833_row0_col28, #T_d8833_row7_col25, #T_d8833_row8_col13, #T_d8833_row14_col9, #T_d8833_row22_col20 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d8833_row0_col29, #T_d8833_row9_col10, #T_d8833_row16_col27, #T_d8833_row22_col27, #T_d8833_row23_col25, #T_d8833_row29_col9, #T_d8833_row31_col26, #T_d8833_row31_col28 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_d8833_row0_col30, #T_d8833_row18_col8, #T_d8833_row23_col12, #T_d8833_row31_col19 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_d8833_row0_col31, #T_d8833_row1_col17, #T_d8833_row3_col31, #T_d8833_row5_col31, #T_d8833_row12_col31, #T_d8833_row13_col31, #T_d8833_row19_col17, #T_d8833_row22_col31, #T_d8833_row30_col16, #T_d8833_row31_col23 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col0, #T_d8833_row2_col0, #T_d8833_row3_col23, #T_d8833_row5_col0, #T_d8833_row6_col0, #T_d8833_row8_col9, #T_d8833_row8_col23, #T_d8833_row12_col0, #T_d8833_row19_col0, #T_d8833_row19_col24, #T_d8833_row21_col0, #T_d8833_row25_col2, #T_d8833_row25_col30, #T_d8833_row30_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col2, #T_d8833_row2_col1, #T_d8833_row2_col6, #T_d8833_row5_col4, #T_d8833_row6_col2, #T_d8833_row12_col4, #T_d8833_row21_col12 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col3, #T_d8833_row12_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col4, #T_d8833_row6_col14, #T_d8833_row14_col1, #T_d8833_row28_col29 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col5, #T_d8833_row2_col4, #T_d8833_row2_col14, #T_d8833_row4_col2, #T_d8833_row5_col1, #T_d8833_row5_col12, #T_d8833_row6_col12, #T_d8833_row12_col5, #T_d8833_row12_col6, #T_d8833_row14_col2, #T_d8833_row21_col14 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col6, #T_d8833_row1_col12, #T_d8833_row4_col14, #T_d8833_row4_col21, #T_d8833_row6_col1, #T_d8833_row12_col1, #T_d8833_row14_col4, #T_d8833_row21_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col7, #T_d8833_row13_col25, #T_d8833_row16_col19, #T_d8833_row23_col18, #T_d8833_row29_col10 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col8, #T_d8833_row7_col23, #T_d8833_row13_col23 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col9, #T_d8833_row3_col24, #T_d8833_row7_col27 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_d8833_row1_col10, #T_d8833_row17_col19, #T_d8833_row21_col17, #T_d8833_row26_col17, #T_d8833_row26_col24, #T_d8833_row31_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col11, #T_d8833_row20_col31, #T_d8833_row29_col22 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col13, #T_d8833_row2_col26, #T_d8833_row14_col30, #T_d8833_row26_col1, #T_d8833_row26_col5, #T_d8833_row30_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col14, #T_d8833_row1_col21, #T_d8833_row4_col5, #T_d8833_row4_col12, #T_d8833_row21_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_d8833_row1_col15, #T_d8833_row7_col18

# %%
coupe_corr = coupe.corr()
coupe_corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_ccfd1_row0_col0, #T_ccfd1_row1_col1, #T_ccfd1_row2_col2, #T_ccfd1_row3_col3, #T_ccfd1_row4_col4, #T_ccfd1_row5_col5, #T_ccfd1_row6_col6, #T_ccfd1_row7_col7, #T_ccfd1_row8_col8, #T_ccfd1_row9_col9, #T_ccfd1_row10_col10, #T_ccfd1_row11_col11, #T_ccfd1_row12_col12, #T_ccfd1_row13_col13, #T_ccfd1_row14_col14, #T_ccfd1_row15_col15, #T_ccfd1_row16_col16, #T_ccfd1_row17_col17, #T_ccfd1_row18_col18, #T_ccfd1_row19_col19, #T_ccfd1_row20_col20, #T_ccfd1_row21_col21, #T_ccfd1_row22_col22, #T_ccfd1_row23_col23, #T_ccfd1_row24_col24, #T_ccfd1_row25_col25, #T_ccfd1_row26_col26, #T_ccfd1_row27_col27, #T_ccfd1_row28_col28, #T_ccfd1_row29_col29, #T_ccfd1_row30_col30, #T_ccfd1_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ccfd1_row0_col1, #T_ccfd1_row18_col8, #T_ccfd1_row23_col12, #T_ccfd1_row31_col19 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ccfd1_row0_col2, #T_ccfd1_row0_col14, #T_ccfd1_row3_col26, #T_ccfd1_row15_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_ccfd1_row0_col3, #T_ccfd1_row2_col17, #T_ccfd1_row3_col6, #T_ccfd1_row12_col7, #T_ccfd1_row12_col10, #T_ccfd1_row18_col10 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ccfd1_row0_col4, #T_ccfd1_row0_col21, #T_ccfd1_row11_col13, #T_ccfd1_row15_col26, #T_ccfd1_row18_col28 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ccfd1_row0_col5, #T_ccfd1_row0_col6, #T_ccfd1_row10_col27, #T_ccfd1_row17_col14, #T_ccfd1_row22_col9, #T_ccfd1_row23_col4, #T_ccfd1_row23_col6, #T_ccfd1_row23_col21, #T_ccfd1_row24_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ccfd1_row0_col7, #T_ccfd1_row0_col10, #T_ccfd1_row3_col20, #T_ccfd1_row7_col1, #T_ccfd1_row28_col24 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ccfd1_row0_col8, #T_ccfd1_row14_col15 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ccfd1_row0_col9, #T_ccfd1_row0_col16, #T_ccfd1_row10_col6, #T_ccfd1_row11_col4, #T_ccfd1_row18_col7, #T_ccfd1_row24_col17, #T_ccfd1_row28_col15 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ccfd1_row0_col11, #T_ccfd1_row16_col26, #T_ccfd1_row20_col10, #T_ccfd1_row22_col30, #T_ccfd1_row23_col11, #T_ccfd1_row31_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T
{
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col2, #T_ccfd1_row2_col1, #T_ccfd1_row2_col6, #T_ccfd1_row5_col4, #T_ccfd1_row6_col2, #T_ccfd1_row12_col4, #T_ccfd1_row21_col12 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col4, #T_ccfd1_row6_col14, #T_ccfd1_row14_col1, #T_ccfd1_row28_col29 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col5, #T_ccfd1_row2_col4, #T_ccfd1_row2_col14, #T_ccfd1_row4_col2, #T_ccfd1_row5_col1, #T_ccfd1_row5_col12, #T_ccfd1_row6_col12, #T_ccfd1_row12_col5, #T_ccfd1_row12_col6, #T_ccfd1_row14_col2, #T_ccfd1_row21_col14 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col6, #T_ccfd1_row1_col12, #T_ccfd1_row4_col14, #T_ccfd1_row4_col21, #T_ccfd1_row6_col1, #T_ccfd1_row12_col1, #T_ccfd1_row14_col4, #T_ccfd1_row21_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col8, #T_ccfd1_row7_col23, #T_ccfd1_row10_col0, #T_ccfd1_row13_col0, #T_ccfd1_row13_col23 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col9, #T_ccfd1_row3_col24, #T_ccfd1_row7_col27 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_ccfd1_row1_col10, #T_ccfd1_row17_col19, #T_ccfd1_row21_col17, #T_ccfd1_row26_col17, #T_ccfd1_row26_col24, #T_ccfd1_row31_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col11, #T_ccfd1_row20_col31, #T_ccfd1_row29_col22 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col13, #T_ccfd1_row2_col26, #T_ccfd1_row14_col30, #T_ccfd1_row26_col1, #T_ccfd1_row26_col5, #T_ccfd1_row30_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col14, #T_ccfd1_row1_col21, #T_ccfd1_row4_col5, #T_ccfd1_row4_col12, #T_ccfd1_row21_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col15, #T_ccfd1_row7_col18, #T_ccfd1_row17_col6, #T_ccfd1_row26_col10, #T_ccfd1_row30_col25 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ccfd1_row1_col16, #T_ccfd1_row1_col25, #T_ccfd1_row17_col30 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col17, #T_ccfd1_row3_col31, #T_ccfd1_row5_col31, #T_ccfd1_row12_col31, #T_ccfd1_row13_col31, #T_ccfd1_row19_col17, #T_ccfd1_row22_col31, #T_ccfd1_row30_col16, #T_ccfd1_row31_col23 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ccfd1_row1_col18, #T_ccfd1_row2_col18, #T_ccfd1_row14_col18, #T_ccfd1_row16_col23, #T_ccfd1_row20_col8, #T_ccfd1_row26_col25 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_33333_row1_col9, #T_33333_row3_col24, #T_33333_row7_col27 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_33333_row1_col10, #T_33333_row17_col19, #T_33333_row21_col17, #T_33333_row26_col17, #T_33333_row26_col24, #T_33333_row31_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_33333_row1_col11, #T_33333_row20_col31, #T_33333_row29_col22 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_33333_row1_col13, #T_33333_row2_col26, #T_33333_row14_col30, #T_33333_row26_col1, #T_33333_row26_col5, #T_33333_row30_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_33333_row1_col14, #T_33333_row1_col21, #T_33333_row4_col5, #T_33333_row4_col12, #T_33333_row21_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_33333_row1_col15, #T_33333_row7_col18, #T_33333_row17_col6, #T_33333_row26_col10, #T_33333_row30_col25 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_33333_row1_col16, #T_33333_row1_col25, #T_33333_row17_col30 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_33333_row1_col18, #T_33333_row2_col18, #T_33333_row14_col18, #T_33333_row16_col23, #T_33333_row20_col8,

# %%
baguette_corr = baguette.corr()
baguette_corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_8add2_row0_col0, #T_8add2_row1_col1, #T_8add2_row2_col2, #T_8add2_row3_col3, #T_8add2_row4_col4, #T_8add2_row5_col5, #T_8add2_row6_col6, #T_8add2_row7_col7, #T_8add2_row8_col8, #T_8add2_row9_col9, #T_8add2_row10_col10, #T_8add2_row11_col11, #T_8add2_row12_col12, #T_8add2_row13_col13, #T_8add2_row14_col14, #T_8add2_row15_col15, #T_8add2_row16_col16, #T_8add2_row17_col17, #T_8add2_row18_col18, #T_8add2_row19_col19, #T_8add2_row20_col20, #T_8add2_row21_col21, #T_8add2_row22_col22, #T_8add2_row23_col23, #T_8add2_row24_col24, #T_8add2_row25_col25, #T_8add2_row26_col26, #T_8add2_row27_col27, #T_8add2_row28_col28, #T_8add2_row29_col29, #T_8add2_row30_col30, #T_8add2_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8add2_row0_col1, #T_8add2_row3_col28, #T_8add2_row16_col4, #T_8add2_row17_col21, #T_8add2_row23_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_8add2_row0_col2, #T_8add2_row0_col14, #T_8add2_row11_col13, #T_8add2_row15_col26, #T_8add2_row18_col28 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_8add2_row0_col3, #T_8add2_row8_col20 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8add2_row0_col4, #T_8add2_row0_col21, #T_8add2_row16_col26, #T_8add2_row20_col10, #T_8add2_row22_col30, #T_8add2_row23_col11, #T_8add2_row31_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_8add2_row0_col5, #T_8add2_row0_col6, #T_8add2_row18_col8, #T_8add2_row23_col12, #T_8add2_row31_col19 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_8add2_row0_col7, #T_8add2_row3_col2, #T_8add2_row8_col26, #T_8add2_row11_col18, #T_8add2_row11_col21, #T_8add2_row14_col7, #T_8add2_row15_col1, #T_8add2_row15_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_8add2_row0_col8, #T_8add2_row0_col15, #T_8add2_row14_col15 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_8add2_row0_col9, #T_8add2_row2_col15, #T_8add2_row10_col19, #T_8add2_row15_col18 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_8add2_row0_col10, #T_8add2_row3_col21, #T_8add2_row7_col20, #T_8add2_row9_col24, #T_8add2_row10_col1, #T_8add2_row11_col14, #T_8add2_row15_col5, #T_8add2_row18_col2, #T_8add2_row22_col15, #T_8add2_row24_col20, #T_8add2_row29_col15, #T_8add2_row29_col24, #T_8add2_row31_col17 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_8add2_row0_col11, #T_8add2_row16_col3, #T_8add2_row17_col28, #T_8add2_row18_col27, #T_8add2_row22_col11, #T_8add2_row24_col29, #T_8add2_row31_col1, #T_8add2_row31_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_8add2_row0_col12, #T_8add2_row10_col27, #T_8add2_row17_col14, #T_8add2_row22_col9, #T_8add2_row23_col4, #T_8add2_row23_col6, #T_8add2_row23_col21, #T_8add2_row24_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_8add2_row0_col13, #T_8add2_row4_col15, #T_8add2_row10_col30, #T_8add2_row13_col16, #T_8add2_row16_col2, #T_8add2_row23_col30, #T_8add2_row27_col17 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_8add2_row0_col16, #T_8add2_row10_col6, #T_8add2_row11_col4, #T_8add2_row18_col7, #T_8add2_row24_col17, #T_8add2_row28_col15 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_8add2_row0_col17, #T_8add2_row17_col5, #T_8add2_row18_col3, #T_8add2_row21_col16, #T_8add2_row25_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_8add2_row0_col18, #T_8add2_row1_col7, #T_8add2_row13_col25, #T_8add2_row16_col19, #T_8add2_row23_col18, #T_8add2_row29_col10 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_8add2_row0_col19, #T_8add2_row11_col29, #T_8add2_row16_col21, #T_8add2_row18_col17, #T_8add2_row23_col5, #T_8add2_row24_col7, #T_8add2_row24_col15, #T_8add2_row31_col13 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_8add2_row0_col20, #T_8add2_row15_col21, #T_8add2_row17_col13, #T_8add2_row23_col20, #T_8add2_row25_col8, #T_8add2_row31_col14 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_8add2_row0_col22, #T_8add2_row3_col23, #T_8add2_row8_col9, #T_8add2_row8_col23, #T_8add2_row19_col24, #T_8add2_row25_col2, #T_8add2_row25_col30 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8add2_row0_col23, #T_8add2_row5_col24, #T_8add2_row12_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_8add2_row0_col24, #T_8add2_row7_col21, #T_8add2_row15_col14, #T_8add2_row17_col26 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_8add2_row0_col25, #T_8add2_row8_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_8add2_row0_col26, #T_8add2_row0_col28, #T_8add2_row7_col13, #T_8add2_row11_col3, #T_8add2_row13_col11, #T_8add2_row15_col28, #T_8add2_row22_col6, #T_8add2_row28_col9, #T_8add2_row31_col25 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_8add2_row0_col27, #T_8add2_row16_col29, #T_8add2_row17_col29, #T_8add2_row18_col11, #T_8add2_row18_col24, #T_8add2_row22_col25, #T_8add2_row23_col27, #T_8add2_row24_col8, #T_8add2_row24_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8add2_row0_col29 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_8add2_row0_col30, #T_8add2_row23_col15, #T_8add2_row27_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_8add2_row0_col31, #T_8add2_row5_col18, #T_8add2_row10_col3, #T_8add2_row20_col18, #T_8add2_row26_col18, #T_8add2_row31_col22 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col0, #T_8add2_row2_col0, #T_8add2_row2_col24, #T_8add2_row3_col22, #T_8add2_row4_col0, #T_8add2_row4_col23, #T_8add2_row5_col0, #T_8add2_row6_col0, #T_8add2_row6_col3, #T_8add2_row9_col7, #T_8add2_row9_col15, #T_8add2_row9_col16, #T_8add2_row9_col17, #T_8add2_row9_col18, #T_8add2_row11_col9, #T_8add2_row11_col10, #T_8add2_row11_col30, #T_8add2_row12_col0, #T_8add2_row14_col0, #T_8add2_row14_col23, #T_8add2_row14_col24, #T_8add2_row19_col0, #T_8add2_row19_col8, #T_8add2_row20_col11, #T_8add2_row21_col0, #T_8add2_row21_col23, #T_8add2_row24_col1, #T_8add2_row24_col2, #T_8add2_row24_col4, #T_8add2_row24_col5, #T_8add2_row24_col13, #T_8add2_row24_col14, #T_8add2_row24_col19, #T_8add2_row24_col21, #T_8add2_row24_col22, #T_8add2_row25_col1, #T_8add2_row25_col5, #T_8add2_row25_col6, #T_8add2_row25_col12, #T_8add2_row25_col20, #T_8add2_row25_col26, #T_8add2_row25_col27, #T_8add2_row25_col28, #T_8add2_row25_col29, #T_8add2_row25_col31, #T_8add2_row26_col0, #T_8add2_row28_col0, #T_8add2_row29_col0, #T_8add2_row29_col25 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col2, #T_8add2_row2_col1, #T_8add2_row2_col6, #T_8add2_row5_col4, #T_8add2_row6_col2, #T_8add2_row12_col4, #T_8add2_row21_col12 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col3, #T_8add2_row9_col0, #T_8add2_row12_col3, #T_8add2_row22_col0, #T_8add2_row31_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col4, #T_8add2_row6_col14, #T_8add2_row14_col1, #T_8add2_row28_col29 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col5, #T_8add2_row2_col4, #T_8add2_row2_col14, #T_8add2_row4_col2, #T_8add2_row5_col1, #T_8add2_row5_col12, #T_8add2_row6_col12, #T_8add2_row12_col5, #T_8add2_row12_col6, #T_8add2_row14_col2, #T_8add2_row21_col14 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col6, #T_8add2_row1_col12, #T_8add2_row4_col14, #T_8add2_row4_col21, #T_8add2_row6_col1, #T_8add2_row12_col1, #T_8add2_row14_col4, #T_8add2_row21_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col8, #T_8add2_row7_col0, #T_8add2_row7_col23, #T_8add2_row11_col0, #T_8add2_row13_col23, #T_8add2_row15_col0, #T_8add2_row16_col0, #T_8add2_row17_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col9, #T_8add2_row3_col24, #T_8add2_row7_col27 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_8add2_row1_col10, #T_8add2_row17_col19, #T_8add2_row21_col17, #T_8add2_row26_col17, #T_8add2_row26_col24, #T_8add2_row31_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col11, #T_8add2_row20_col31, #T_8add2_row29_col22 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8add2_row1_col13, #T_8add2_row2_col26, #T_8ad

# %%
banette_corr = banette.corr()
banette_corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
