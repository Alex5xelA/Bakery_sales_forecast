# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %% [markdown]
# ## 1.1  EDA Sales Data

# %%
# !pwd
# Out:
# /home/javier/code/Bakery_sales_forecast/Bakery_sales_foreacst/notebooks

# %%
data_sales = pd.read_csv('../raw_data/bakerysales.csv')

# %%
data_sales.head()
# Out:
#    Unnamed: 0        date   time  ticket_number               article  \
# 0           0  2021-01-02  08:38       150040.0              BAGUETTE
# 1           1  2021-01-02  08:38       150040.0      PAIN AU CHOCOLAT
# 2           4  2021-01-02  09:14       150041.0      PAIN AU CHOCOLAT
# 3           5  2021-01-02  09:14       150041.0                  PAIN
# 4           8  2021-01-02  09:25       150042.0  TRADITIONAL BAGUETTE
#
#    Quantity unit_price
# 0       1.0     0,90 €
# 1       3.0     1,20 €
# 2       2.0     1,20 €
# 3       1.0     1,15 €
# 4       5.0     1,20 €

# %%
df_sales = data_sales.drop(columns=['Unnamed: 0'])
df_sales.head()
# Out:
#          date   time  ticket_number               article  Quantity unit_price
# 0  2021-01-02  08:38       150040.0              BAGUETTE       1.0     0,90 €
# 1  2021-01-02  08:38       150040.0      PAIN AU CHOCOLAT       3.0     1,20 €
# 2  2021-01-02  09:14       150041.0      PAIN AU CHOCOLAT       2.0     1,20 €
# 3  2021-01-02  09:14       150041.0                  PAIN       1.0     1,15 €
# 4  2021-01-02  09:25       150042.0  TRADITIONAL BAGUETTE       5.0     1,20 €

# %%
# Converting dates to datetime object
df_sales['date'] = pd.to_datetime(df_sales['date'])
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234005 entries, 0 to 234004
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           234005 non-null  datetime64[ns]
#  1   time           234005 non-null  object
#  2   ticket_number  234005 non-null  float64
#  3   article        234005 non-null  object
#  4   Quantity       234005 non-null  float64
#  5   unit_price     234005 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 10.7+ MB

# %%
df_sales.head()
# Out:
#         date   time  ticket_number               article  Quantity unit_price
# 0 2021-01-02  08:38       150040.0              BAGUETTE       1.0     0,90 €
# 1 2021-01-02  08:38       150040.0      PAIN AU CHOCOLAT       3.0     1,20 €
# 2 2021-01-02  09:14       150041.0      PAIN AU CHOCOLAT       2.0     1,20 €
# 3 2021-01-02  09:14       150041.0                  PAIN       1.0     1,15 €
# 4 2021-01-02  09:25       150042.0  TRADITIONAL BAGUETTE       5.0     1,20 €

# %%
df_sales['hour_min'] = df_sales['time'].apply(lambda x: datetime.strptime(x,'%H:%M' ).time())
df_sales.head()
# Out:
#         date   time  ticket_number               article  Quantity unit_price  \
# 0 2021-01-02  08:38       150040.0              BAGUETTE       1.0     0,90 €
# 1 2021-01-02  08:38       150040.0      PAIN AU CHOCOLAT       3.0     1,20 €
# 2 2021-01-02  09:14       150041.0      PAIN AU CHOCOLAT       2.0     1,20 €
# 3 2021-01-02  09:14       150041.0                  PAIN       1.0     1,15 €
# 4 2021-01-02  09:25       150042.0  TRADITIONAL BAGUETTE       5.0     1,20 €
#
#    hour_min
# 0  08:38:00
# 1  08:38:00
# 2  09:14:00
# 3  09:14:00
# 4  09:25:00

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234005 entries, 0 to 234004
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           234005 non-null  datetime64[ns]
#  1   time           234005 non-null  object
#  2   ticket_number  234005 non-null  float64
#  3   article        234005 non-null  object
#  4   Quantity       234005 non-null  float64
#  5   unit_price     234005 non-null  object
#  6   hour_min       234005 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 12.5+ MB

# %%
df_sales.shape
# Out:
# (234005, 6)

# %%
df_sales['unit_price'] = df_sales['unit_price'].str.replace("€","").str.replace(",",".")
df_sales.head()
# Out:
#         date      time  ticket_number               article  Quantity  \
# 0 2021-01-02  08:38:00       150040.0              BAGUETTE       1.0
# 1 2021-01-02  08:38:00       150040.0      PAIN AU CHOCOLAT       3.0
# 2 2021-01-02  09:14:00       150041.0      PAIN AU CHOCOLAT       2.0
# 3 2021-01-02  09:14:00       150041.0                  PAIN       1.0
# 4 2021-01-02  09:25:00       150042.0  TRADITIONAL BAGUETTE       5.0
#
#   unit_price
# 0      0.90
# 1      1.20
# 2      1.20
# 3      1.15
# 4      1.20

# %%
df_sales['unit_price'] = pd.to_numeric(df_sales['unit_price'])
df_sales.head()
# Out:
#         date      time  ticket_number               article  Quantity  \
# 0 2021-01-02  08:38:00       150040.0              BAGUETTE       1.0
# 1 2021-01-02  08:38:00       150040.0      PAIN AU CHOCOLAT       3.0
# 2 2021-01-02  09:14:00       150041.0      PAIN AU CHOCOLAT       2.0
# 3 2021-01-02  09:14:00       150041.0                  PAIN       1.0
# 4 2021-01-02  09:25:00       150042.0  TRADITIONAL BAGUETTE       5.0
#
#    unit_price
# 0        0.90
# 1        1.20
# 2        1.20
# 3        1.15
# 4        1.20

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234005 entries, 0 to 234004
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           234005 non-null  datetime64[ns]
#  1   time           234005 non-null  object
#  2   ticket_number  234005 non-null  float64
#  3   article        234005 non-null  object
#  4   Quantity       234005 non-null  float64
#  5   unit_price     234005 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 10.7+ MB

# %%
df_sales.describe()
# Out:
#                                 date  ticket_number       Quantity  \
# count                         234005  234005.000000  234005.000000
# mean   2021-11-30 11:33:31.049336576  219201.258738       1.538377
# min              2021-01-02 00:00:00  150040.000000    -200.000000
# 25%              2021-07-03 00:00:00  184754.000000       1.000000
# 50%              2021-11-04 00:00:00  218807.000000       1.000000
# 75%              2022-05-31 00:00:00  253927.000000       2.000000
# max              2022-09-30 00:00:00  288913.000000     200.000000
# std                              NaN   40053.223896       1.289603
#
#           unit_price
# count  234005.000000
# mean        1.662195
# min         0.000000
# 25%         1.100000
# 50%         1.200000
# 75%         1.500000
# max        60.000000
# std         1.722720

# %%
# Setting dates as the index
df_sales.set_index(['date'], inplace=True)
df_sales.head()
# Out:
#                 time  ticket_number               article  Quantity  \
# date
# 2021-01-02  08:38:00       150040.0              BAGUETTE       1.0
# 2021-01-02  08:38:00       150040.0      PAIN AU CHOCOLAT       3.0
# 2021-01-02  09:14:00       150041.0      PAIN AU CHOCOLAT       2.0
# 2021-01-02  09:14:00       150041.0                  PAIN       1.0
# 2021-01-02  09:25:00       150042.0  TRADITIONAL BAGUETTE       5.0
#
#             unit_price
# date
# 2021-01-02        0.90
# 2021-01-02        1.20
# 2021-01-02        1.20
# 2021-01-02        1.15
# 2021-01-02        1.20

# %% [markdown]
# ## 1.2 EDA Weather Data

# %%
data_weather = pd.read_csv('../raw_data/paris_weather.csv')

# %%
df_weather = data_weather
df_weather.head()
# Out:
#          DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0  01/01/2021                  3                  2                  7
# 1  02/01/2021                  5                 -1                  7
# 2  03/01/2021                  4                  2                 10
# 3  04/01/2021                  3                  2                 13
# 4  05/01/2021                  3                  2                 14
#
#    TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                      2                   3                      3
# 1                      2                   4                      4
# 2                      3                   3                      3
# 3                      2                   2                      3
# 4                      2                   2                      3
#
#    PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                  0.5                    86              7.750  ...
# 1                  0.1                    76             10.000  ...
# 2                  0.3                    92             10.000  ...
# 3                  1.0                    95              6.875  ...
# 4                  0.4                    94              7.750  ...
#
#    WEATHER_CODE_MORNING  WEATHER_CODE_NOON  WEATHER_CODE_EVENING  \
# 0                   116                332                   122
# 1                   122                116                   116
# 2                   122                116                   119
# 3                   332                326                   332
# 4                   326                332                   371
#
#    TOTAL_SNOW_MM  UV_INDEX  SUNHOUR                 OPINION    SUNSET  \
# 0            0.3         1      3.2  météo très défavorable  17:05:00
# 1            0.0         1      8.6  météo très défavorable  17:06:00
# 2            0.0         1      8.6  météo très défavorable  17:07:00
# 3            0.7         1      3.2  météo très défavorable  17:08:00
# 4            0.1         1      3.2  météo très défavorable  17:09:00
#
#     SUNRISE  TEMPERATURE_NIGHT_C
# 0  08:44:00                    2
# 1  08:44:00                    3
# 2  08:44:00                    3
# 3  08:44:00                    2
# 4  08:43:00                    2
#
# [5 rows x 25 columns]

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE                    638 non-null    object
#  1   MAX_TEMPERATURE_C       638 non-null    int64
#  2   MIN_TEMPERATURE_C       638 non-null    int64
#  3   WINDSPEED_MAX_KMH       638 non-null    int64
#  4   TEMPERATURE_MORNING_C   638 non-null    int64
#  5   TEMPERATURE_NOON_C      638 non-null    int64
#  6   TEMPERATURE_EVENING_C   638 non-null    int64
#  7   PRECIP_TOTAL_DAY_MM     638 non-null    float64
#  8   HUMIDITY_MAX_PERCENT    638 non-null    int64
#  9   VISIBILITY_AVG_KM       638 non-null    float64
#  10  PRESSURE_MAX_MB         638 non-null    int64
#  11  CLOUDCOVER_AVG_PERCENT  638 non-null    float64
#  12  HEATINDEX_MAX_C         638 non-null    int64
#  13  DEWPOINT_MAX_C          638 non-null    int64
#  14  WINDTEMP_MAX_C          638 non-null    int64
#  15  WEATHER_CODE_MORNING    638 non-null    int64
#  16  WEATHER_CODE_NOON       638 non-null    int64
#  17  WEATHER_CODE_EVENING    638 non-null    int64
#  18  TOTAL_SNOW_MM           638 non-null    float64
#  19  UV_INDEX                638 non-null    int64
#  20  SUNHOUR                 638 non-null    float64
#  21  OPINION                 638 non-null    object
#  22  SUNSET                  638 non-null    object
#  23  SUNRISE                 638 non-null    object
#  24  TEMPERATURE_NIGHT_C     638 non-null    int64
# dtypes: float64(5), int64(16), object(4)
# memory usage: 124.7+ KB

# %%
df_weather.head()
# Out:
#          DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0  01/01/2021                  3                  2                  7
# 1  02/01/2021                  5                 -1                  7
# 2  03/01/2021                  4                  2                 10
# 3  04/01/2021                  3                  2                 13
# 4  05/01/2021                  3                  2                 14
#
#    TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                      2                   3                      3
# 1                      2                   4                      4
# 2                      3                   3                      3
# 3                      2                   2                      3
# 4                      2                   2                      3
#
#    PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                  0.5                    86              7.750  ...
# 1                  0.1                    76             10.000  ...
# 2                  0.3                    92             10.000  ...
# 3                  1.0                    95              6.875  ...
# 4                  0.4                    94              7.750  ...
#
#    WEATHER_CODE_MORNING  WEATHER_CODE_NOON  WEATHER_CODE_EVENING  \
# 0                   116                332                   122
# 1                   122                116                   116
# 2                   122                116                   119
# 3                   332                326                   332
# 4                   326                332                   371
#
#    TOTAL_SNOW_MM  UV_INDEX  SUNHOUR                 OPINION    SUNSET  \
# 0            0.3         1      3.2  météo très défavorable  17:05:00
# 1            0.0         1      8.6  météo très défavorable  17:06:00
# 2            0.0         1      8.6  météo très défavorable  17:07:00
# 3            0.7         1      3.2  météo très défavorable  17:08:00
# 4            0.1         1      3.2  météo très défavorable  17:09:00
#
#     SUNRISE  TEMPERATURE_NIGHT_C
# 0  08:44:00                    2
# 1  08:44:00                    3
# 2  08:44:00                    3
# 3  08:44:00                    2
# 4  08:43:00                    2
#
# [5 rows x 25 columns]

# %%
# Out:
# datetime.date(2021, 1, 2)

# %%
df_weather
# Out:
#         Unnamed: 0        date   time  ticket_number               article  \
# 0                0  2021-01-02  08:38       150040.0              BAGUETTE
# 1                1  2021-01-02  08:38       150040.0      PAIN AU CHOCOLAT
# 2                4  2021-01-02  09:14       150041.0      PAIN AU CHOCOLAT
# 3                5  2021-01-02  09:14       150041.0                  PAIN
# 4                8  2021-01-02  09:25       150042.0  TRADITIONAL BAGUETTE
# ...            ...         ...    ...            ...                   ...
# 234000      511387  2022-09-30  18:52       288911.0                 COUPE
# 234001      511388  2022-09-30  18:52       288911.0            BOULE 200G
# 234002      511389  2022-09-30  18:52       288911.0                 COUPE
# 234003      511392  2022-09-30  18:55       288912.0  TRADITIONAL BAGUETTE
# 234004      511395  2022-09-30  18:56       288913.0  TRADITIONAL BAGUETTE
#
#         Quantity unit_price
# 0            1.0     0,90 €
# 1            3.0     1,20 €
# 2            2.0     1,20 €
# 3            1.0     1,15 €
# 4            5.0     1,20 €
# ...          ...        ...
# 234000       1.0     0,15 €
# 234001       1.0     1,20 €
# 234002       2.0     0,15 €
# 234003       1.0     1,30 €
# 234004       1.0     1,30 €
#
# [234005 rows x 7 columns]
